# %%
# David Beck
# CSC578-701
# HW2

import NN578_network2 as network2
import numpy as np

# Load the iris train-test (separate) data files
def my_load_csv(fname, no_trainfeatures, no_testfeatures):
    ret = np.genfromtxt(fname, delimiter=',')
    data = np.array([(entry[:no_trainfeatures],entry[no_trainfeatures:]) for entry in ret])
    temp_inputs = [np.reshape(x, (no_trainfeatures, 1)) for x in data[:,0]]
    temp_results = [np.reshape(y, (no_testfeatures, 1)) for y in data[:,1]]
    dataset = list(zip(temp_inputs, temp_results))
    return dataset

iris_train = my_load_csv('../data/iris-train-1.csv', 4, 3)
iris_test = my_load_csv('../data/iris-test-1.csv', 4, 3)

# %% [markdown]
# ## (1) Small experiment with One-training-One-test Iris data
#
# ### [You can run the start-up code as is to generate these.]

# %%
# Test with one-data Iris data

inst1 = (np.array([5.7, 3, 4.2, 1.2]), np.array([0., 1., 0.]))
x1 = np.reshape(inst1[0], (4, 1))
y1 = np.reshape(inst1[1], (3, 1))
sample1 = [(x1, y1)]
inst2 = (np.array([4.8, 3.4, 1.6, 0.2]), np.array([1., 0., 0.]))
x2 = np.reshape(inst2[0], (4, 1))
y2 = np.reshape(inst2[1], (3, 1))
sample2 = [(x2, y2)]

net4 = network2.load_network("iris-423.dat")
net4.set_parameters(cost=network2.QuadraticCost)

net4.SGD(sample1, 2, 1, 1.0, evaluation_data=sample2, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.26673128660052947
# Accuracy on training data: 1 / 1
# Cost on evaluation data: 0.3244002758397572
# Accuracy on evaluation data: 0 / 1
#
# Epoch 1 training complete
# Cost on training data: 0.2107866577006649
# Accuracy on training data: 1 / 1
# Cost on evaluation data: 0.37647122809828165
# Accuracy on evaluation data: 0 / 1
# ([0.3244002758397572, 0.37647122809828165],
#  [0, 0],
#  [0.26673128660052947, 0.2107866577006649],
#  [1, 1])

# %% [markdown]
# ## (2) Experiments with Iris train-test-1 datasets, with random-shuffle suppressed training
# ##   (2-1) Sigmoid + QuadraticCost [You can run the start-up code as is to generate this.]

# %%
net2 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net2.set_parameters(cost=network2.QuadraticCost)

net2.SGD(iris_train, 10, 1, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.23511052948021774
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.23887527012577628
# Accuracy on evaluation data: 35 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.18455113694871084
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.19259471015802
# Accuracy on evaluation data: 35 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.1746888670684831
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1835496893958853
# Accuracy on evaluation data: 35 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.17088787461067578
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17937927946978807
# Accuracy on evaluation data: 35 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.16990642674912537
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17822748490175794
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.16952151503854623
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1778135860232122
# Accuracy on evaluation data: 35 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.16359259470352153
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17063240182026004
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.16617108130552838
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1739019090965302
# Accuracy on evaluation data: 35 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.16877864308890245
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17715961328275948
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.16812677240779994
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.17636324096598513
# Accuracy on evaluation data: 35 / 55
# ([0.23887527012577628,
#   0.19259471015802,
#   0.1835496893958853,
#   0.17937927946978807,
#   0.17822748490175794,
#   0.1778135860232122,
#   0.17063240182026004,
#   0.1739019090965302,
#   0.17715961328275948,
#   0.17636324096598513],
#  [35, 35, 35, 35, 35, 35, 35, 35, 35, 35],
#  [0.23511052948021774,
#   0.18455113694871084,
#   0.1746888670684831,
#   0.17088787461067578,
#   0.16990642674912537,
#   0.16952151503854623,
#   0.16359259470352153,
#   0.16617108130552838,
#   0.16877864308890245,
#   0.16812677240779994],
#  [65, 65, 65, 65, 65, 65, 65, 65, 65, 65])

# %% [markdown]
# ## (2-2) Sigmoid + CrossEntropyCost

# %%
net3 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net3.set_parameters(cost=network2.CrossEntropyCost)

net3.SGD(iris_train, 10, 1, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.9263678377944575
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1
aluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.3327121708105555
# Accuracy on training data: 53 / 95
# Cost on evaluation data: 0.3459512186718889
# Accuracy on evaluation data: 26 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.3296675066258744
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.3474981444425265
# Accuracy on evaluation data: 35 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.3272395642528617
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.34869937921229593
# Accuracy on evaluation data: 35 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3262196938285744
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.34964253990504335
# Accuracy on evaluation data: 35 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3256832086709506
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.3501589230080171
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.3253133777807362
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.3504621545284812
# Accuracy on evaluation data: 35 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.32501167277184545
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.3506882194886744
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.3247445540535348
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.3508837108006664
# Accuracy on evaluation data: 35 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.3244995951430809
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.35106170501358336
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.3242718075797425
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.35122612573230794
# Accuracy on evaluation data: 35 / 55
# ([0.3459512186718889,
#   0.3474981444425265,
#   0.34869937921229593,
#   0.34964253990504335,
#   0.3501589230080171,
#   0.3504621545284812,
#   0.3506882194886744,
#   0.3508837108006664,
#   0.35106170501358336,
#   0.35122612573230794],
#  [26, 35, 35, 35, 35, 35, 35, 35, 35, 35],
#  [0.3327121708105555,
#   0.3296675066258744,
#   0.3272395642528617,
#   0.3262196938285744,
#   0.3256832086709506,
#   0.3253133777807362,
#   0.32501167277184545,
#   0.3247445540535348,
#   0.3244995951430809,
#   0.3242718075797425],
#  [53, 65, 65, 65, 65, 65, 65, 65, 65, 65])

# %% [markdown]
# ## (2-10) Sigmoid + QuadraticCost with L1 regularization with lmbda = 3.0

# %%
net1 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net1.set_parameters(cost=network2.QuadraticCost, regularization='L1')

net1.SGD(iris_train, 10, 1, 1.0, lmbda = 3.0,
            evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.3430822521839076
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3524590058206078
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.3411388229367505
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.34957209748853835
# Accuracy on evaluation data: 18 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.3407788206999967
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3487795317927317
# Accuracy on evaluation data: 18 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.34045220152126415
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.34817054461605335
# Accuracy on evaluation data: 18 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3417150676852247
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.350159829180449
# Accuracy on evaluation data: 18 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.3425508122577549
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.35194807223194424
# Accuracy on evaluation data: 18 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.3401928745385011
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3475488390218029
# Accuracy on evaluation data: 18 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.3419252098779211
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.35074518200421934
# Accuracy on evaluation data: 18 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.3417773203039222
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.350539309376974
# Accuracy on evaluation data: 18 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.341586364881391
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3503867855824889
# Accuracy on evaluation data: 18 / 55
# ([0.3524590058206078,
#   0.34957209748853835,
#   0.3487795317927317,
#   0.34817054461605335,
#   0.350159829180449,
#   0.35194807223194424,
#   0.3475488390218029,
#   0.35074518200421934,
#   0.350539309376974,
#   0.3503867855824889],
#  [18, 18, 18, 18, 18, 18, 18, 18, 18, 18],
#  [0.3430822521839076,
#   0.3411388229367505,
#   0.3407788206999967,
#   0.34045220152126415,
#   0.3417150676852247,
#   0.3425508122577549,
#   0.3401928745385011,
#   0.3419252098779211,
#   0.3417773203039222,
#   0.341586364881391],
#  [32, 32, 32, 32, 32, 32, 32, 32, 32, 32])

# %% [markdown]
# ## (2-11) ReLU hidden + Softmax output + LogLikelihood cost with L2 regularization with lmbda = 3.0

# %%
net1 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net1.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.ReLU, 
                    act_output=network2.Softmax, regularization='L2')

net1.SGD(iris_train, 10, 1, 1.0, lmbda = 3.0,
            evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.251577752506748
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.3306141821496207
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.1671212605998662
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1847347870377731
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.166931224885037
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.184406543530341
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.1669307972853098
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058049489938
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.1669307963231668
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032871105
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.1669307963210018
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.184405803283371
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
# ([1.3306141821496207,
#   1.1847347870377731,
#   1.184406543530341,
#   1.1844058049489938,
#   1.1844058032871105,
#   1.184405803283371,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17],
#  [1.251577752506748,
#   1.1671212605998662,
#   1.166931224885037,
#   1.1669307972853098,
#   1.1669307963231668,
#   1.1669307963210018,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33])

# %%
## (2-12) ReLU hidden + Softmax output + LogLikelihood cost with L1 regularization with lmbda = 3.0

# %%
net1 = network2.load_network("iris-423.dat")

# Set hyper-parameter values individually after the network
net1.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.ReLU, 
                    act_output=network2.Softmax, regularization='L1')

net1.SGD(iris_train, 10, 1, 1.0, lmbda = 3.0,
            evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# /resources/NNDLcode_Py3_CSC578/src/NN578_network2.py:140: RuntimeWarning: invalid value encountered in true_divide
#   return np.divide(np.exp(z), np.sum(np.exp(z)), out=np.zeros_like(z), where=(np.sum(np.exp(z)!=0)))
# Epoch 0 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 2 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 3 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 4 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 5 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 6 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 7 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 8 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
#
# Epoch 9 training complete
# Cost on training data: nan
# Accuracy on training data: 32 / 95
# Cost on evaluation data: nan
# Accuracy on evaluation data: 18 / 55
# ([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [18, 18, 18, 18, 18, 18, 18, 18, 18, 18],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [32, 32, 32, 32, 32, 32, 32, 32, 32, 32])

# %% [markdown]
# ## (3) Experiments with "iris-4-20-7-3.dat", with random-shuffle suppressed training
# ##   (3-1) ReLU + Softmax + LogLikelihood with Dropout = 0.1

# %%
net2 = network2.load_network("iris-4-20-7-3.dat")

# Set hyper-parameter values individually after the network
net2.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.ReLU,
                   act_output=network2.Softmax, dropoutpercent=0.3)

net2.SGD(iris_train, 10, 1, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.1669307963133315
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032714042
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
# ([1.1844058032714042,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17],
#  [1.1669307963133315,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33])

# %% [markdown]
# ## (3-2) Sigmoid + QuadraticCost with Dropout = 0.3

# %%
net1 = network2.load_network("iris-4-20-7-3.dat")

# Set hyper-parameter values individually after the network
net1.set_parameters(cost=network2.QuadraticCost, dropoutpercent=0.3)

net1.SGD(iris_train, 10, 1, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.3597461799529097
# test data
# Accuracy on training data: 30 / 95
# Cost on evaluation data: 0.35207748901640445
# Accuracy on evaluation data: 20 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.4108628040759387
# test data
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3424478760308989
# Accuracy on evaluation data: 18 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.37746356178959783
# test data
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.3417455889396253
# Accuracy on evaluation data: 18 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.3120507907709237
# test data
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.30947260481064914
# Accuracy on evaluation data: 35 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.3391812359993866
# test data
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.26592760882407906
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.3484979711178185
# test data
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.2615721406120445
# Accuracy on evaluation data: 35 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.3885100290454001
# test data
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.23445984961252242
# Accuracy on evaluation data: 35 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.33425412245457187
# test data
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.19869536255999254
# Accuracy on evaluation data: 38 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.3396657958814014
# test data
# Accuracy on training data: 73 / 95
# Cost on evaluation data: 0.19958378366323623
# Accuracy on evaluation data: 47 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.23122617610730486
# test data
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.21079627772002454
# Accuracy on evaluation data: 38 / 55
# ([0.35207748901640445,
#   0.3424478760308989,
#   0.3417455889396253,
#   0.30947260481064914,
#   0.26592760882407906,
#   0.2615721406120445,
#   0.23445984961252242,
#   0.19869536255999254,
#   0.19958378366323623,
#   0.21079627772002454],
#  [20, 18, 18, 35, 35, 35, 35, 38, 47, 38],
#  [0.3597461799529097,
#   0.4108628040759387,
#   0.37746356178959783,
#   0.3120507907709237,
#   0.3391812359993866,
#   0.3484979711178185,
#   0.3885100290454001,
#   0.33425412245457187,
#   0.3396657958814014,
#   0.23122617610730486],
#  [30, 32, 32, 65, 65, 65, 64, 62, 73, 62])

# %% [markdown]
# ## (3-3) Sigmoid + QuadraticCost with Dropout = 0.5

# %%
net1 = network2.load_network("iris-4-20-7-3.dat")

# Set hyper-parameter values individually after the network
net1.set_parameters(cost=network2.QuadraticCost, dropoutpercent=0.5)

net1.SGD(iris_train, 10, 1, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 0.33952382943137116
# test data
# Accuracy on training data: 32 / 95
# Cost on evaluation data: 0.347586879331294
# Accuracy on evaluation data: 18 / 55
#
# Epoch 1 training complete
# Cost on training data: 0.3445795148478141
# test data
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.31504520935427005
# Accuracy on evaluation data: 35 / 55
#
# Epoch 2 training complete
# Cost on training data: 0.23682565424281127
# test data
# Accuracy on training data: 63 / 95
# Cost on evaluation data: 0.24100193567308223
# Accuracy on evaluation data: 32 / 55
#
# Epoch 3 training complete
# Cost on training data: 0.28882918844296673
# test data
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.2164825206522676
# Accuracy on evaluation data: 35 / 55
#
# Epoch 4 training complete
# Cost on training data: 0.1937080978164586
# test data
# Accuracy on training data: 64 / 95
# Cost on evaluation data: 0.17376308951752015
# Accuracy on evaluation data: 35 / 55
#
# Epoch 5 training complete
# Cost on training data: 0.24380842434986283
# test data
# Accuracy on training data: 63 / 95
# Cost on evaluation data: 0.17206924770808366
# Accuracy on evaluation data: 38 / 55
#
# Epoch 6 training complete
# Cost on training data: 0.21686872857719186
# test data
# Accuracy on training data: 67 / 95
# Cost on evaluation data: 0.1731240558782186
# Accuracy on evaluation data: 42 / 55
#
# Epoch 7 training complete
# Cost on training data: 0.17285085955097637
# test data
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1700894864221675
# Accuracy on evaluation data: 35 / 55
#
# Epoch 8 training complete
# Cost on training data: 0.2382309572764967
# test data
# Accuracy on training data: 65 / 95
# Cost on evaluation data: 0.1682626746407983
# Accuracy on evaluation data: 35 / 55
#
# Epoch 9 training complete
# Cost on training data: 0.21239730425696693
# test data
# Accuracy on training data: 62 / 95
# Cost on evaluation data: 0.16667881004110385
# Accuracy on evaluation data: 38 / 55
# ([0.347586879331294,
#   0.31504520935427005,
#   0.24100193567308223,
#   0.2164825206522676,
#   0.17376308951752015,
#   0.17206924770808366,
#   0.1731240558782186,
#   0.1700894864221675,
#   0.1682626746407983,
#   0.16667881004110385],
#  [18, 35, 32, 35, 35, 38, 42, 35, 35, 38],
#  [0.33952382943137116,
#   0.3445795148478141,
#   0.23682565424281127,
#   0.28882918844296673,
#   0.1937080978164586,
#   0.24380842434986283,
#   0.21686872857719186,
#   0.17285085955097637,
#   0.2382309572764967,
#   0.21239730425696693],
#  [32, 65, 63, 65, 64, 63, 67, 65, 65, 62])

# %%
##   (3-4) ReLU + Softmax + LogLikelihood with Dropout = 0.5

# %%
net2 = network2.load_network("iris-4-20-7-3.dat")

# Set hyper-parameter values individually after the network
net2.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.ReLU,
                   act_output=network2.Softmax, dropoutpercent=0.5)

net2.SGD(iris_train, 10, 1, 1.0, evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.1669307966448546
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058037863543
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.166930796320997
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
# ([1.1844058037863543,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17],
#  [1.1669307966448546,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997,
#   1.166930796320997],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33])

# %%
##   (3-5) ReLU + Softmax + LogLikelihood + L2 + Lambda=3.0 with Dropout = 0.1

# %%
net2 = network2.load_network("iris-4-20-7-3.dat")

# Set hyper-parameter values individually after the network
net2.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.ReLU,
                   act_output=network2.Softmax, dropoutpercent=0.1)

net2.SGD(iris_train, 10, 1, 1.0, lmbda = 3.0,
            evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 3.4933633229289773
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 5.202789258260949
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.1721655066214145
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1934475756204477
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.166942574952709
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844261481926834
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.166930822824119
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058490614822
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.166930796380632
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.184405803386368
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.1669307963211313
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032835945
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.1669307963209974
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.184405803283363
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.1669307963209972
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.1669307963209972
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.1669307963209972
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
# ([5.202789258260949,
#   1.1934475756204477,
#   1.1844261481926834,
#   1.1844058490614822,
#   1.184405803386368,
#   1.1844058032835945,
#   1.184405803283363,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17],
#  [3.4933633229289773,
#   1.1721655066214145,
#   1.166942574952709,
#   1.166930822824119,
#   1.166930796380632,
#   1.1669307963211313,
#   1.1669307963209974,
#   1.1669307963209972,
#   1.1669307963209972,
#   1.1669307963209972],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33])

# %%
##   (3-6) ReLU + Softmax + LogLikelihood + L2 + Lambda=3.0 with Dropout = 0.5

# %%
net2 = network2.load_network("iris-4-20-7-3.dat")

# Set hyper-parameter values individually after the network
net2.set_parameters(cost=network2.LogLikelihood, act_hidden=network2.ReLU,
                   act_output=network2.Softmax, dropoutpercent=0.5)

net2.SGD(iris_train, 10, 1, 1.0, lmbda = 3.0,
            evaluation_data=iris_test, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.8121267659909825
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 2.298835205440212
# Accuracy on evaluation data: 17 / 55
#
# Epoch 1 training complete
# Cost on training data: 1.1683825530129064
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1869133830239336
# Accuracy on evaluation data: 17 / 55
#
# Epoch 2 training complete
# Cost on training data: 1.1669340629215208
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844114455933583
# Accuracy on evaluation data: 17 / 55
#
# Epoch 3 training complete
# Cost on training data: 1.1669308036711812
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058159791353
# Accuracy on evaluation data: 17 / 55
#
# Epoch 4 training complete
# Cost on training data: 1.166930796337536
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058033119294
# Accuracy on evaluation data: 17 / 55
#
# Epoch 5 training complete
# Cost on training data: 1.1669307963210345
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032834268
# Accuracy on evaluation data: 17 / 55
#
# Epoch 6 training complete
# Cost on training data: 1.1669307963209972
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833629
# Accuracy on evaluation data: 17 / 55
#
# Epoch 7 training complete
# Cost on training data: 1.1669307963209972
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 8 training complete
# Cost on training data: 1.1669307963209972
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
#
# Epoch 9 training complete
# Cost on training data: 1.1669307963209972
# Accuracy on training data: 33 / 95
# Cost on evaluation data: 1.1844058032833626
# Accuracy on evaluation data: 17 / 55
# ([2.298835205440212,
#   1.1869133830239336,
#   1.1844114455933583,
#   1.1844058159791353,
#   1.1844058033119294,
#   1.1844058032834268,
#   1.1844058032833629,
#   1.1844058032833626,
#   1.1844058032833626,
#   1.1844058032833626],
#  [17, 17, 17, 17, 17, 17, 17, 17, 17, 17],
#  [1.8121267659909825,
#   1.1683825530129064,
#   1.1669340629215208,
#   1.1669308036711812,
#   1.166930796337536,
#   1.1669307963210345,
#   1.1669307963209972,
#   1.1669307963209972,
#   1.1669307963209972,
#   1.1669307963209972],
#  [33, 33, 33, 33, 33, 33, 33, 33, 33, 33])

# %% [markdown]
# ## (4) Experiments with MNIST dataset
# ##   (4-1) Sigmoid, Softmax, LogLikelihood

# %%
import mnist_loader
net1 = network2.load_network("mnist_net1.dat") #saved network
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()

# Set hyper-parameter values individually after the network
net1.set_parameters(cost=network2.LogLikelihood, act_hidden = network2.Sigmoid, act_output = network2.Softmax)

net1.SGD(training_data, 10, 10, 3.0, evaluation_data=test_data, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)

# %% [markdown]
# ##   (4-2) Sigmoid, Softmax, LogLikelihood, with L2 regularization with lmbda=1.5

# %%
net9 = network2.load_network("mnist_net1.dat") #saved network
#training_data, validation_data, test_data = mnist_loader.load_data_wrapper()

# Set hyper-parameter values individually after the network
net9.set_parameters(cost=network2.LogLikelihood, act_hidden = network2.Sigmoid, act_output = network2.Softmax,
                   regularization='L2')

net9.SGD(training_data, 10, 10, 3.0, lmbda=1.5,
         evaluation_data=test_data, monitor_evaluation_cost=True, 
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)
